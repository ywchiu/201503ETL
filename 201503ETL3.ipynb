# %%
import requests
res = requests.get("http://www.google.com.tw")
#print res.text

# %%
import requests
payload = {"key":"val"}
print payload["key"]
# Out:
# val

# %%
import requests
payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }
res = requests.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance', data=payload)
#print res.text

# %%
pagenum = 265 / 100

# %%
pagenum
# Out:
# 2

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__name__',
#  '__package__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'hypot',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'modf',
#  'pi',
#  'pow',
#  'radians',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'trunc']

# %%
print (265 * 1.0) / 100
# Out:
# 2.65

# %%
help(math.ceil)
print math.ceil((265 * 1.0) / 100 )
# Out:
# Help on built-in function ceil in module math:
#
# ceil(...)
#     ceil(x)
#
#     Return the ceiling of x as a float.
#     This is the smallest integral value >= x.
#
# 3.0

# %%
import requests
rs_get = requests.get("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2")
#print rs_get.text

# %%
import requests
rs = requests.session()
res = rs.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance', data=payload)
res2 = rs.get("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2")
#print res2.text

# %%
import requests
res = requests.get("http://twtraffic.tra.gov.tw/twrail/SearchResult.aspx?searchtype=0&searchdate=2015/03/18&fromstation=1810&tostation=1809&trainclass=%271100%27,%271101%27,%271102%27,%271107%27,%271110%27,%271120%27&fromtime=0600&totime=2359")
#print res.text

# %%
import requests
qoo = {
'StartStation':'977abb69-413a-4ccf-a109-0272c24fd490',
'EndStation':'fbd828d8-b1da-4b06-a3bd-680cdca4d2cd',
'SearchDate':'2015/03/18',
'SearchTime':'10:30',
'SearchWay':'DepartureInMandarin'
}
res = requests.post('http://www.thsrc.com.tw/tw/TimeTable/SearchResult', data=qoo)
#print res.text

# %%
import requests
import re
import json
res = requests.get("http://www.pinkoi.com/browse")
ele = re.search("pinkoi.browse.renderHighlight\('#hightlight', (.*)\);", res.text)
#ele = re.search("pinkoi.browse.renderHighlight\('#hightlight', (.*)\);", res.text)
jele = json.loads(ele.group().split("#hightlight', ")[1].split(');')[0])
for item in jele:
    print item['title']
# Out:
# 【義賣】柴犬MARU 感謝你的愛 - 義賣限定版明信片組 (12張入)
# 潘裕文《永不結束的馬拉松》 公益合作 簽名單曲
# Bon Bon Stickers 妃炫少女 全身少女22入澎湃組
# 好日推好物商品：一次收藏組：女孩叄拾明信片書＋貼紙
# 宇宙小貓們 ! galaxy cat !(一對入)  手作耳針-不過敏鋼針/可改夾式-旋轉可調鬆緊
# 女孩叄拾貼紙組 30張入
# YIZISTORE 半圓口金包 小挎包 收納包
# 小孩市集獨立誌#05 - 一起練習組（練習紙膠帶 + 明信片）
# YIZISTORE 半圓零錢包 化妝包 收納包
# 好日推好物商品：後背包＿藍黑
# ❛巧克力包裹❜12片入(一盒)
# 甜蜜生活2015版萬年曆圖案貼紙組 九張入
# 【限時免運】無所事事慵懶貓／牛仔鬚鬚漁夫帽
# 女牛仔褲 SKINNY JEANS
# 雞排+芒果冰 英文版 明信片組(兩入) 小白襪 歪國人愛台味

# %%
import requests
import json
res = requests.get("https://www.google.com.tw/search?tbm=nws&q=%E7%BF%9F%E6%9C%AC%E5%96%AC&ion=1&espv=2&fp=792ce4bb3a36bf70&bav=on.2,or.r_cp.&cad=b&biw=1137&bih=262&dpr=0.9&tch=1&ech=1&psi=WeUIVeqJMord8AXlq4GoDg.1426646362088.3")
#print res.text
#print json.loads(res.text.split('/*""*/')[0])

# %%
import requests
from bs4 import BeautifulSoup
rs = requests.session()
res = rs.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance', data=payload)
soup = BeautifulSoup(res.text) # 把回傳文字放到BeautifulSoup 中
pagenum = soup.select('.T11b') # 抓出class=T11b 的區塊 class = . id = #
print pagenum
# Out:
# [<span class="T11b" style="color: red;">265</span>]

# %%
print pagenum[0].text
print float(pagenum[0].text) / 100
import math
print math.ceil(float(pagenum[0].text) / 100)
print int(math.ceil(float(pagenum[0].text) / 100))
pagenumbers = int(math.ceil(float(pagenum[0].text) / 100))
#print pagenum
print "pagenumber = %d"%(pagenumbers)
# Out:
# 265
# 2.65
# 3.0
# 3
# pagenumber = 3

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("http://www.backpackers.com.tw/forum/forumdisplay.php?s=0065fcda3fd7e7cc61c5278979b2416f&f=43")
soup = BeautifulSoup(res.text)
entries  = soup.select("#threadbits_forum_43 div")
#for entry in entries:
#    print entry.select(".alt1 div:nth-child(1)")[0].text

# %%
for entry in entries:
    if len(entry.select('a')) > 0:
        if entry.select('a')[0].text != "":
            print entry.select('a')[0].text
# Out:
#
#
#
#
#
#
# 【推薦】東京觀光景點速覽（可大幅縮短尋找資料的時間）
#
#
# 東京LINK(實用網站)
# [公告]關於機票轉讓等二手票券販售公告
#
# 3大1小(2歲)  五天四夜 行程建議
# 請問我該如何選擇訂房人數?
# 小江戶特急
# 東京5天4夜自由行~
# 东京8天自由行
# 晴空塔行程疑問請教
# 11月東京近郊六日行程請教
# 9/17~9/21 東京 五天四夜 行程安排
# 這行程會不會太貪心??!!
# google map
# 不好意思，求解
# 上野公園點燈市集
# 請問東京要去哪裡買媽媽穿的休閒服或睡衣？
#
# 中目黑夜櫻與千鳥之淵點燈後選擇
# 東京自助旅行 行程建議 麻煩各位達人了!
# 新手東京五天四夜行程請益
#
# 東京7天6夜行程求指教
# 成田機場搭NEX至品川轉車一問
#
#
# 角屋跟新宿太陽道..價位差不多該選..?
#
#
# super hotel池袋北口是否可刷卡?
# Skyliner & Tickets 新組合，2000日幣，36分到東京市區！
# JR東日本網站
# 日本行程請教

# %%
#print pagenumbers
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
for page in range(1, pagenumbers + 1): 
    #print page
    print page_format%(page)
# Out:
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=1
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=3

# %%
import requests
payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }
rs = requests.session()
res = rs.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance', data=payload)
soup = BeautifulSoup(res.text) # 把回傳文字放到BeautifulSoup 中
page_number  = int(math.ceil(float(soup.select('.T11b')[0].text) / 100)) # 抓出class=T11b 的區塊 class = . id = #


page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = rs.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8')

# %%
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
page = 1
bid_list = rs.get(page_format%(page)) 
bid_response = bid_list.text.encode('utf8')
soup = BeautifulSoup(bid_response)
bid_table = soup.select("#print_area")[0]
print bid_table #this is a comment
# Out:
# <div id="print_area">
# <table border="0" cellpadding="0" cellspacing="0" style="word-break:break-all" width="100%">
# <tr>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">項次 </td>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="15%">機關 <br/>名稱 </td>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="30%">標案案號 <br/>標案名稱 </td>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="10%">招標 <br/>方式 </td>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="8%">標的 <br/>分類 </td>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="9%">公告 <br/>日期 </td>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="13%">決標 <br/>金額 </td>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">決標 <br/>公告 </td>
# <td align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">無法 <br/>決標 </td>
# </tr>
# ...

# %%
bid_rows = bid_table.select('tr')[1:-1]
#print bid_rows

# %%
qoo  = [1,2,3,4,5]
print qoo
# Out:
# [1, 2, 3, 4, 5]

# %%
print qoo[1:] # 去頭 
print qoo[:-1] # 去尾
print qoo[1:-1] # 去頭去尾留中間
# Out:
# [2, 3, 4, 5]
# [1, 2, 3, 4]
# [2, 3, 4]

# %%
bid_rows = bid_table.select('tr')[1:-1] 
for bid_row in bid_rows: 
    #links = [tag['href'] 
    #  for tag in bid_row.select('a')] 
    for tag in bid_row.select('a'):
        print tag['href']
# Out:
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241675&tenderCaseNo=XW03118P099
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241675&tenderCaseNo=XW03118P099
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241674&tenderCaseNo=XW03072P119
# ...

# %%
bid_rows = bid_table.select('tr')[1:-1] 
for bid_row in bid_rows: 
    links = [tag['href'] for tag in bid_row.select('a')] 
    print links[0]
# Out:
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241675&tenderCaseNo=XW03118P099
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241674&tenderCaseNo=XW03072P119
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241666&tenderCaseNo=B1030411
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241665&tenderCaseNo=B1030422
# ../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241621&tenderCaseNo=MPB10390429
# ...

# %%
original= "http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197"
extracted="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197"
print extracted[2:]  
print "http://web.pcc.gov.tw/tps" + extracted[2:]
# Out:
# /main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197

# %%
bid_rows = bid_table.select('tr')[1:-1] 
for bid_row in bid_rows: 
    links = [tag['href'] for tag in bid_row.select('a')] 
    extracted =  links[0]
    print "http://web.pcc.gov.tw/tps" + extracted[2:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241675&tenderCaseNo=XW03118P099
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241674&tenderCaseNo=XW03072P119
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241666&tenderCaseNo=B1030411
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241665&tenderCaseNo=B1030422
# ...

# %%
import requests
from bs4 import BeautifulSoup
import json
res = requests.get("http://graphics8.nytimes.com/packages/js/nytint/projects/tax_incentives/states/grants/AL.json?true=grants")

jele = json.loads(res.text.split("grants(")[1].encode('utf-8').strip(")"))
for ele in  jele:
    s = BeautifulSoup(ele[2])
    print ele[0], ele[1], s.text, ele[3]
# Out:
# 1417496 $1.42 million Frank's WholesaleAlabama Industrial Development Training 87
# 589828 $589,828 Helix Systems, Inc.Alabama Industrial Development Training 60
# 726930 $726,930  ABB, Inc.  Alabama Industrial Development Training 56
# 284994 $284,994 Global KnowledgeAlabama Industrial Development Training 48
# 124845 $124,845 SAP AMERICAAlabama Industrial Development Training 32
# 159592 $159,592 Evans Mahon, Inc.Alabama Industrial Development Training 31
# 39358 $39,358 Advantage Training Solutions.Alabama Industrial Development Training 30
# 319067 $319,067 Rockwell AutomationAlabama Industrial Development Training 28
# 92366 $92,366 Society Automotive EngineeringAlabama Industrial Development Training 28
# 133391 $133,391 American Management AssociationAlabama Industrial Development Training 27
# 191466 $191,466 Spectrum RoboticsAlabama Industrial Development Training 26
# 153707 $153,707 IBMAlabama Industrial Development Training 25
# ...

# %%
#table[0].select("span")

# %%
import requests
import re
qoo = {'lib':'mobile',
'prod_id':'4935'}
res = requests.post("http://www.eprice.com.tw/ajax/intro/price.history.get.php", data=qoo)
res.encoding = 'utf-8'

m = re.search('<data><date>(.*)</date><price>(.*)</price></data>', res.text)
print m.groups()
# Out:
# (u'<![CDATA[2014-03-24]]></date><price><![CDATA[22957]]></price></data><data><date><![CDATA[2014-03-31]]></date><price><![CDATA[23900]]></price></data><data><date><![CDATA[2014-04-07]]></date><price><![CDATA[23900]]></price></data><data><date><![CDATA[2014-04-14]]></date><price><![CDATA[23900]]></price></data><data><date><![CDATA[2014-04-21]]></date><price><![CDATA[23900]]></price></data><data><date><![CDATA[2014-04-28]]></date><price><![CDATA[23900]]></price></data><data><date><![CDATA[2014-05-05]]></date><price><![CDATA[23900]]></price></data><data><date><![CDATA[2014-05-12]]></date><price><![CDATA[22900]]></price></data><data><date><![CDATA[2014-05-19]]></date><price><![CDATA[21901]]></price></data><data><date><![CDATA[2014-05-26]]></date><price><![CDATA[21157]]></price></data><data><date><![CDATA[2014-06-02]]></date><price><![CDATA[20334]]></price></data><data><date><![CDATA[2014-06-09]]></date><price><![CDATA[19318]]></price></data><data><date><![CDATA[2014-06-16]]></date><price
# ...

# %%
a = '<data>12345</data>'
import re 
m = re.match('<data>(.*)</data>', a)
print m

# %%
bid_rows = bid_table.select('tr')[1:-1] 
for bid_row in bid_rows: 
    links = [tag['href'] for tag in bid_row.select('a')] 
    extracted =  links[0]
    print "http://web.pcc.gov.tw/tps" + extracted[2:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241675&tenderCaseNo=XW03118P099
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241674&tenderCaseNo=XW03072P119
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241666&tenderCaseNo=B1030411
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51241665&tenderCaseNo=B1030422
# ...

# %%
f = open("test.txt", 'w') 
f.write("Hello World\n") 
f.close()

# %%
import requests
payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }
rs = requests.session()
res = rs.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance', data=payload)
soup = BeautifulSoup(res.text) # 把回傳文字放到BeautifulSoup 中
page_number  = int(math.ceil(float(soup.select('.T11b')[0].text) / 100)) # 抓出class=T11b 的區塊 class = . id = #

import urlparse

bid_file = open("bid_list.txt", 'w') 
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = rs.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8') 
    bid_soup = BeautifulSoup(bid_response) 
    bid_table = bid_soup.select("#print_area")[0]
    bid_rows = bid_table.select('tr')[1:-1] 
    for bid_row in bid_rows:         
        link = [tag['href'] for tag in bid_row.select('a')][0] 
        link_href = urlparse.urljoin("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", link) 
        bid_file.write(link_href + "\n") 
bid_file.close()

# %%
# -*- coding: utf-8 -*- 
import requests
import urlparse 
from bs4 import BeautifulSoup 
from math import ceil

# %%
payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }

rs = requests.session() 
user_post = rs.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload) 
response_text = user_post.text.encode('utf8')

# %%
soup = BeautifulSoup(response_text) 
rec_number_element = soup.select(".T11b" )[0] 
rec_number = int(rec_number_element.text)
page_number = int(ceil(float(rec_number) / 100))

# %%
bid_file = open("bid_list.txt", 'w') 
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = rs.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8') 
    bid_soup = BeautifulSoup(bid_response)
    bid_table = bid_soup.select("#print_area")[0] 
    bid_rows = bid_table.select('tr')[1:-1] 
    for bid_row in bid_rows: 
        link = [tag['href'] for tag in bid_row.select('a')][0] 
        link_href = urlparse.urljoin("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", link) 
        bid_file.write(link_href + "\n") 
bid_file.close()

# %%
bid_file = open("bid_list.txt", 'r')
cnt = 0 
for line in bid_file.readlines():
    cnt += 1
print cnt
bid_file.close()

bid_file = open("bid_list.txt", 'r')
print len([line for line in bid_file.readlines()])
bid_file.close()
# Out:
# 265
# 265

# %%
assert 1!=1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-206-0131bef69216> in <module>()
# ----> 1 assert 1!=1
#
# AssertionError:

# %%
assert 1==1

# %%
import requests
res = requests.get("http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51240739&tenderCaseNo=G103EDU043")
#print res.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text)
pa = soup.select("#printArea")
print pa
# Out:
# [<div class="main" id="printArea">
#
#               	﻿﻿﻿﻿﻿<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <head>
# <link href="/tps/styles/text.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/css.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/chtd_tab.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/chtd.css" rel="stylesheet" type="text/css"/>
# <style>
# td {align: left;}
# </style>
# </head>
# <script>
# $jq(document).ready(function(){
# 	popWatermark();
# });
#
# function openEditScreen(editUrl){
#     window.open(encodeURI(editUrl));
#     unblock();
# }
#
# function popWatermark(){
# 	        var msgTop = 50;
# 	        var msgLeft = 500;
#
# 	        try{
# 	        	msgTop = $jq("#printArea").position().top+50;
# 	        	msgLeft = $jq("#printArea").position().left +$jq("#printArea").width()/2 +50;
# 			}catch(e) {}
#
# 			$jq("#hidden_message_id")
# 	        .css({
# ...

# %%
link = "../main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197"
url = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance"
import urlparse
print urlparse.urljoin(url, link)
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197

# %%
print "http://web.pcc.gov.tw/tps"+ link[2:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239371&tenderCaseNo=4197

# %%
bid_detail = open("bid_detail.txt", 'w') 
request_get = requests.get("http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328") 
response = request_get.text.encode('utf8') 
soup = BeautifulSoup(response)
printarea = soup.select('#printArea') [0]
#print type(printarea.prettify('utf-8'))
bid_detail.write(printarea.prettify('utf-8')) 
bid_detail.close()

# %%
a = 'http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=50912982&tenderCaseNo=01102001'
print a.split('tenderCaseNo=')[1]
print a.split('pkAtmMain=')[1]
print a.split('pkAtmMain=')[1].split('&tenderCaseNo=')
# Out:
# 01102001
# 50912982&tenderCaseNo=01102001
# ['50912982', '01102001']

# %%
case_dic = {} 
f = open("bid_list.txt", "r") 
for line in f.readlines(): 
    rec = line.strip() 
    caseno = rec.split('tenderCaseNo=')[1] 
    if caseno not in case_dic: 
        case_dic[caseno] = 1 
    else: 
        print line 
f.close()
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239526&tenderCaseNo=1030401
#
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239201&tenderCaseNo=10302
#
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51240026&tenderCaseNo=10302
#
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51240096&tenderCaseNo=103003
#
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239351&tenderCaseNo=1030415

# %%
link = "http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328" 

rear_substring = link.split("pkAtmMain=")[1] 
param = rear_substring.split("&tenderCaseNo=") 
pkAtmMain= param[0] 
caseno= param[1] 
print pkAtmMain,caseno
# Out:
# 51239291 0607L1030328

# %%
import re 
m = re.match(r"(?P<qoo>\w+) (?P<oop>\w+)", "Barack Obama") 
print m.group("qoo"), m.group("oop")
# Out:
# Barack Obama

# %%
import re 
link = "http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328" 
m = re.match(r"([^ ]+)pkAtmMain=(?P<qoo>.+)&tenderCaseNo=(?P<oop>.+)", link) 
print m.group('qoo'), m.group('oop')
# Out:
# 51239291 0607L1030328

# %%
import re
email="david@largitdata.com"
m = re.match("(.*)@(.*)", email)
print m.groups()
print m.group(1)
print m.group(2)
# Out:
# ('david', 'largitdata.com')
# david
# largitdata.com

# %%
import re
email="david@largitdata.com"
m = re.match("(?P<name>.*)@(?P<hostname>.*)", email)
print m.groups()
print m.group(1)
print m.group(2)

print m.group('name') # == m.group(1)
print m.group('hostname') # == m.group(2)
# Out:
# ('david', 'largitdata.com')
# david
# largitdata.com
# david
# largitdata.com

# %%
# -*- coding: utf-8 -*- 
from bs4 import BeautifulSoup 
import re, requests 

bid_list = open('bid_list.txt', 'r') 
for line in bid_list.readlines(): 
    pagelink = line.strip() 
    m = re.match(r"([^ ]+)pkAtmMain=(?P<pkAtmMain>.+)&tenderCaseNo=(?P<tenderCaseNo>.+)", pagelink) 
    filename = "%s_%s"%(m.group('pkAtmMain'), m.group('tenderCaseNo')) 
    
    request_get = requests.get(pagelink) 
    response = request_get.text.encode('utf8') 
    soup = BeautifulSoup(response) 
    printarea = soup.select('#printArea')[0] 
    bid_detail = open("gov/%s.txt"%(filename), 'w') 
    bid_detail.write(printarea.prettify("utf-8")) 
    bid_detail.close() 
bid_list.close()

# %%
import time 
time.sleep(5)

# %%
# -*- coding: utf-8 -*- 
from bs4 import BeautifulSoup 
import re, requests 
import time
bid_list = open('bid_list.txt', 'r') 
for line in bid_list.readlines(): 
    pagelink = line.strip() 
    m = re.match(r"([^ ]+)pkAtmMain=(?P<pkAtmMain>.+)&tenderCaseNo=(?P<tenderCaseNo>.+)", pagelink) 
    filename = "%s_%s"%(m.group('pkAtmMain'), m.group('tenderCaseNo')) 
    
    request_get = requests.get(pagelink) 
    response = request_get.text.encode('utf8') 
    soup = BeautifulSoup(response) 
    printarea = soup.select('#printArea')[0] 
    bid_detail = open("gov/%s.txt"%(filename), 'w') 
    bid_detail.write(printarea.prettify("utf-8")) 
    bid_detail.close() 
    #time.sleep(1)
bid_list.close()

# %%
a = "        david@largitdata.com        "
import re
m = re.match("([^ ]*)@([^ ]*)",a)
print m
m = re.match(".*?([^ ]*)@([^ ]*).*",a)
print m.group(1), m.group(2)

m = re.search("([^ ]*)@([^ ]*)",a)
print m.group(1), m.group(2)
# Out:
# None
# david largitdata.com
# david largitdata.com

# %%
# facebook crawler
import requests
import json 
res = requests.get("https://graph.facebook.com/v2.2/me/friends?access_token=<accesstoken>")
data = json.loads(res.text)['data']
for friend in data:
    print friend['name'], friend['id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-256-da6952e4c0f0> in <module>()
#       3 import json
#       4 res = requests.get("https://graph.facebook.com/v2.2/me/friends?access_token=<accesstoken>")
# ----> 5 data = json.loads(res.text)['data']
#       6 for friend in data:
#       7     print friend['name'], friend['id']
#
# KeyError: 'data'

# %%
#ptt crawler
import requests
res = requests.get("https://www.ptt.cc/bbs/food/index.html", verify=False)
soup = BeautifulSoup(res.text)
entries  = soup.select(".r-ent")
for item in entries:
    print item.select(".title")[0].text.strip(), item.select(".author")[0].text.strip()
# Out:
# [食記] 台北公館 巷仔內平價大份量的十二巷拉麵 jiannjiau
# Fw: [食記] 宜蘭礁溪-三民大飯店-滷豬腳、豬尾巴 luckbear04
# [食記] 中和｜民安街夜市牛の鬼牛排館 fia123
# [廣宣] 台北 豚馬日本料理 有溫度的服務和料理！ shiang0504
# [食記] 台北 好滴咖啡 飲料強 鹹食弱 MinaGD
# [食記] 新北市 三峽 大阪根 大推 山中奇雞 sorimachi18
# [食記] 台北安和 Amber Café早午餐的新選擇 jiannjiau
# [食記] 香港中環翠華餐廳‧24小時營業 changfong
# [食記] 玫瑰草莓果醬‧香港文華東方酒店 changfong
# [請益] 台北能DIY大阪燒/文字燒的店家 panasonic89
# [請益] 尋找以前吃過的一間台北茶餐廳 Hanedas
# [食記] 台南 赤崁擔仔麵(總店) alamodeala
# [食記] 台北 大安 涓豆腐敦南店 anliway
# [食記] 東方文華CAFE UN DEUX TROIS|香氛下午茶 windfree
# [公告] Food板 板規 V3.7 Dilbert
# 精華區使用方法  【重要！新手必看！】 Yawper
# [公告] 發文請在標題加上地區及提供地址電話。^^ bluefish
# [公告] 文章被刪除者請洽精華區的資源回收桶 Dilbert
# [公告] 板規16發文標題須含餐廳店名之調整 Dilbert

# %%
#news crawler
import requests
res = requests.get("http://udn.com/news/breaknews/1/1")
#print res.encoding
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text)
entries  = soup.select("tr")[1:]
for item in entries:
    print item.select('td')[0].text
# Out:
# 蘇起：兩岸交流談判最好不要中斷
# 辜寬敏改挺「穿裙子的」：支持蔡英文
# 柯文哲：還沒正式邀請蘇起任兩岸智囊
# 青年節該哪天？ 網友：318才是台灣青年節
# 柯文哲：大巨蛋安檢延至4月15日出爐
# 謝長廷：莫忘318學運的起因
# 兩黨談憲改消息曝光 吳釗燮遺憾
# 藍委邀馬朱王聚餐 王金平盼團結
# 蘇起：綠若不認九二共識 可提更好藥方
# 民國黨成立 進軍明年立委選戰
# 學運周年 朱立倫：青年是未來希望
# 矯正署長吳憲璋 身體不適准辭
# 國防部：不規劃向俄羅斯買潛艦
# 陳為廷：我們不想造神  未來應有規範
# 兩黨談憲改 國民黨堅持不涉統獨
# 318週年  政院：我們永遠是一家人
# 繞行立院  林義雄：盼公投法修法成功
# 挺賴瑞隆  郭玟成促陳信瑜辭議員
# 回應318 政院：實現跨世代正義
# 若再佔機關 內政部：該怎麼辦就怎麼辦
# 318周年  綠委促修選罷法及公投法
# 回應318 行政院：我們永遠是一家人
# 馬總統出席「2015年臺北國際自行車展」
# 辜寬敏說「無條件」支持蔡英文
# 學運一周年 全國憲改聯盟成立
# 台10萬人詐陸民？刑事局提數據澄清
# 陳肇隆今獲頒外交之友貢獻獎章
# 藍綠「李吳會」週四下午登場
# 海軍敦睦支隊 上午前往蘇澳
# 學運週年  曾銘宗：更重視分配
# 性產業好不好  柯文哲：很難回答
# 縮短工時案  朝野立委紛提案
# 318週年 總統府維安層層把關
# 太陽花學運週年  兩岸協商面臨瓶頸
# 柯文哲：2014年影響最大的是318學運
# 318集會  內政部：警依法行政
# 軟體植入監督不法  立委籲留意
# 拒期末綁投票 學生會串連提早考
# 科技部長沒臉書  立委批與「婉君」脫節
# 蘇起說未被徵詢 柯：還沒正式邀請啦
# 318滿周年 柯：現在去不可能坐地上
# 馬盼吳選總統？ 府：絕無此事
# 藍綠秘書長再溝通  柯建銘：明天拜會
# 太陽花學運周年 黃國昌、陳為廷重返立院
# 全國憲改聯盟成立
# 318週年 府：謙卑聆聽各界聲音
# 終於第一！段宜康自嘲：我是立法院怕老婆第一
# 太陽花學運周年 立法院警方維安配置束帶
# 基本工資  勞動部長：今年有調漲空間
# 太陽花學運周年 柯P：革命尚未成功
# 江宜樺返台奔喪 表情凝重未發言
# ...

# %%
#stock crawler
import requests
res = requests.get("http://www.twse.com.tw/ch/trading/exchange/FMTQIK/genpage/Report201503/201503_F3_1_2.php?STK_NO=&myear=2015&mmon=03")
#print res.encoding
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text.encode('utf-8'))
table  = soup.select(".board_trad")[0]
rows = table.select('tr')[2:]
for tr in rows:
    for i in range(0,6):
        print tr.select('td')[i].text,
    print
    #print tr.select('td')[0].text, tr.select('td')[1].text, tr.select('td')[2].text, tr.select('td')[3].text, tr.select('td')[4].text, tr.select('td')[5].text
# Out:
# 104/03/02 4,459,205,379 92,829,887,227 837,359 9,601.36 -20.74
# 104/03/03 4,446,559,381 85,986,600,442 784,334 9,605.77 4.41
# 104/03/04 4,539,189,625 85,082,416,047 812,771 9,621.73 15.96
# 104/03/05 4,635,460,608 85,930,112,407 790,586 9,595.09 -26.64
# 104/03/06 4,783,179,259 95,779,164,094 827,891 9,645.77 50.68
# 104/03/09 4,400,900,883 86,761,858,898 772,160 9,562.98 -82.79
# 104/03/10 4,731,732,681 93,135,038,990 860,284 9,536.53 -26.45
# 104/03/11 5,039,426,812 97,041,708,916 892,462 9,523.18 -13.35
# 104/03/12 5,614,913,860 97,163,348,938 908,970 9,596.00 72.82
# 104/03/13 4,765,227,785 88,452,992,419 795,705 9,579.35 -16.65
# 104/03/16 4,272,083,203 83,938,633,831 765,183 9,512.91 -66.44
# 104/03/17 5,065,590,882 98,232,445,611 858,373 9,539.44 26.53
# 104/03/18 5,474,093,845 105,213,664,075 950,121 9,653.43 113.99

# %%
phone = ['0912345678', '0912-345678', '0912-345-678', '091234567899999']
import re
for i in range(0, len(phone)):
    m = re.match(r'(^\d{4}-?\d{3}-?\d{3}$)', phone[i])
    if m is not None:
        print m.groups()
# ?P<name>
# Out:
# ('0912345678',)
# ('0912-345678',)
# ('0912-345-678',)

# %%
import requests
res = requests.get("http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51081295&tenderCaseNo=102-0400-1-051")
soup = BeautifulSoup(res.text.encode('utf-8'))
printArea  = soup.select("#printArea")[0]
f = open("51081295_102-0400-1-051.txt", 'w')
f.write(printArea.prettify('utf-8'))
f.close()

# %%
# -*- coding: utf-8 -*- 
from bs4 import BeautifulSoup 
f = open('51081295_102-0400-1-051.txt', 'r') 
response_text = f.read() 
f.close() 

soup = BeautifulSoup(response_text) 
tr = soup.select('tr')
# select 
for row in tr: 
    if len(row.select('th')) >0:
        print row.select('th')[0].text.strip()
# Out:
# 機關代碼
# 機關名稱
# 單位名稱
# 機關地址
# 聯絡人
# 聯絡電話
# 傳真號碼
# 標案案號
# 招標方式
# 決標方式
# 是否依「機關異質採購
#
#       最低標作業須知」辦理
# 新增公告傳輸次數
# 標案名稱
# 決標資料類別
# 是否屬共同供應契約採購
# 是否複數決標
# 是否共同投標
# 標的分類
# 是否屬統包
# 是否應依公共工程專業技師簽證規則實施技師簽證
# 開標時間
# 原公告日期
# 採購金額級距
# 辦理方式
# 預算金額是否公開
# 是否受機關補助
# 履約地點
# 履約地點（含地區）
# 是否屬優先採購身心障礙福利機構產品或勞務
# 是否含特別預算
# 歸屬計畫類別
# 本案採購契約是否採用主管機關訂定之範本
# 投標廠商家數
# 投標廠商家數
# 投標廠商1
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 廠商業別
# 廠商地址
# 廠商電話
# 得標廠商國別
# 是否為中小企業
# 履約起迄日期
# 雇用員工總人數是否
#
#          超過100人
# 僱用員工總
#
#          人數
# 已僱用原住民
#
#          人數
# 已僱用身心障礙者
#
#          人數
# 投標廠商2
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 投標廠商3
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 投標廠商4
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 投標廠商5
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 決標品項數
# 決標品項數
# 第1品項
# 品項名稱
# 是否以單價及預估需
#
#          求數量之乘積決定最
#
#           低標
# 得標廠商1
# 得標廠商
# 預估需求數量
# 原產地國別
# 未得標廠商1
# 未得標廠商
# 是否合格
# 未得標原因
# 標價偏低理由
# 未得標廠商2
# 未得標廠商
# 是否合格
# 未得標原因
# 標價偏低理由
# 未得標廠商3
# 未得標廠商
# 是否合格
# 未得標原因
# 標價偏低理由
# 未得標廠商4
# 未得標廠商
# 是否合格
# 未得標原因
# 標價偏低理由
# 決標公告序號
# 決標日期
# 決標公告日期
# ...

# %%
a = '      adfadf dfdfdfd          \n'
#print a
print a.strip()
# Out:
# adfadf dfdfdfd

# %%
# -*- coding: utf-8 -*- 
from bs4 import BeautifulSoup 
f = open('51081295_102-0400-1-051.txt', 'r') 
response_text = f.read() 
f.close() 

soup = BeautifulSoup(response_text) 
tr = soup.select('tr')
# find 
for row in tr: 
    if row.find('th') is not None:
        print row.find('th').text.strip()
# Out:
# 機關代碼
# 機關名稱
# 單位名稱
# 機關地址
# 聯絡人
# 聯絡電話
# 傳真號碼
# 標案案號
# 招標方式
# 決標方式
# 是否依「機關異質採購
#
#       最低標作業須知」辦理
# 新增公告傳輸次數
# 標案名稱
# 決標資料類別
# 是否屬共同供應契約採購
# 是否複數決標
# 是否共同投標
# 標的分類
# 是否屬統包
# 是否應依公共工程專業技師簽證規則實施技師簽證
# 開標時間
# 原公告日期
# 採購金額級距
# 辦理方式
# 預算金額是否公開
# 是否受機關補助
# 履約地點
# 履約地點（含地區）
# 是否屬優先採購身心障礙福利機構產品或勞務
# 是否含特別預算
# 歸屬計畫類別
# 本案採購契約是否採用主管機關訂定之範本
# 投標廠商家數
# 投標廠商家數
# 投標廠商1
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 廠商業別
# 廠商地址
# 廠商電話
# 得標廠商國別
# 是否為中小企業
# 履約起迄日期
# 雇用員工總人數是否
#
#          超過100人
# 僱用員工總
#
#          人數
# 已僱用原住民
#
#          人數
# 已僱用身心障礙者
#
#          人數
# 投標廠商2
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 投標廠商3
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 投標廠商4
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 投標廠商5
# 廠商代碼
# 廠商名稱
# 是否得標
# 組織型態
# 決標品項數
# 決標品項數
# 第1品項
# 品項名稱
# 是否以單價及預估需
#
#          求數量之乘積決定最
#
#           低標
# 得標廠商1
# 得標廠商
# 預估需求數量
# 原產地國別
# 未得標廠商1
# 未得標廠商
# 是否合格
# 未得標原因
# 標價偏低理由
# 未得標廠商2
# 未得標廠商
# 是否合格
# 未得標原因
# 標價偏低理由
# 未得標廠商3
# 未得標廠商
# 是否合格
# 未得標原因
# 標價偏低理由
# 未得標廠商4
# 未得標廠商
# 是否合格
# 未得標原因
# 標價偏低理由
# 決標公告序號
# 決標日期
# 決標公告日期
# ...

# %%
for row in tr: 
    if row.find('th') is not None:
        if row.find('th').text.encode('utf-8').strip() == "機關代碼":
            print row.find('td').text.strip()
# Out:
# 3.7.74.37

# %%
s = " \t string test \t \n\n\r" ' \t string test \t \n\n\r' 
print s
print s.strip()
print s.rstrip()
print s.lstrip()
# Out:
#  	 string test
#
#  	 string test
#
#
# string test
#
#  	 string test
#  	 string test
#
#  	 string test
# string test
#
#  	 string test

# %%
for row in tr: 
    th = row.find('th') 
    if th is not None: 
        if th.text.encode('utf-8').strip() == "機關代碼": 
            print row.find('td').text.strip() 
        if th.text.encode('utf-8').strip() == "機關名稱": 
            print row.find('td').text.strip()
# Out:
# 3.7.74.37
# 臺灣菸酒股份有限公司隆田酒廠

# %%
dic = {"機關代碼":"", "機關名稱":"", "機關地址":""}
dic["聯絡人"] = ""
print dic
for item in dic:
    print item, dic[item]
for row in tr: 
    th = row.find('th') 
    if th is not None: 
        if th.text.encode('utf-8').strip() in dic: 
            #print th.text.encode('utf-8').strip()
            print row.find('td').text.strip()
# Out:
# {'\xe8\x81\xaf\xe7\xb5\xa1\xe4\xba\xba': '', '\xe6\xa9\x9f\xe9\x97\x9c\xe5\x90\x8d\xe7\xa8\xb1': '', '\xe6\xa9\x9f\xe9\x97\x9c\xe4\xbb\xa3\xe7\xa2\xbc': '', '\xe6\xa9\x9f\xe9\x97\x9c\xe5\x9c\xb0\xe5\x9d\x80': ''}
# 聯絡人
# 機關名稱
# 機關代碼
# 機關地址
# 3.7.74.37
# 臺灣菸酒股份有限公司隆田酒廠
# 720臺南市官田區隆本里中華路一段335號
# 張淑英

# %%
dic = {"機關代碼":"", "機關名稱":"", "機關地址":""}
dic["聯絡人"] = ""
#print dic
#for item in dic:
#    print item, dic[item]
for row in tr: 
    th = row.find('th') 
    if th is not None: 
        if th.text.encode('utf-8').strip() in dic: 
            dic[th.text.encode('utf-8').strip()] = row.find('td').text.strip()

for item in dic:
    print item, dic[item]
# Out:
# 聯絡人 張淑英
# 機關名稱 臺灣菸酒股份有限公司隆田酒廠
# 機關代碼 3.7.74.37
# 機關地址 720臺南市官田區隆本里中華路一段335號
